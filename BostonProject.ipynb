# %%
#Load BeautifulSoup library
import requests
from bs4 import BeautifulSoup
url_to_scrape = 'https://en.wikipedia.org/wiki/Boston'

# %%
r = requests.get(url_to_scrape)

# We now have the source of the page, let's ask BeaultifulSoup
# to parse it for us.
soup = BeautifulSoup(r.text,'lxml')
soup.title #Verify if we get the page or not
# Out:
# <title>Boston - Wikipedia</title>

# %%
import numpy as np # library to handle data in a vectorized manner

import pandas as pd # library for data analsysis
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json # library to handle JSON files

#!conda install -c conda-forge geopy --yes # uncomment this line if you haven't completed the Foursquare API lab
from geopy.geocoders import Nominatim # convert an address into latitude and longitude values

import requests # library to handle requests
from pandas.io.json import json_normalize # tranform JSON file into a pandas dataframe

# Matplotlib and associated plotting modules
import matplotlib.cm as cm
import matplotlib.colors as colors

# import k-means from clustering stage
from sklearn.cluster import KMeans

#!conda install -c conda-forge folium=0.5.0 --yes # uncomment this line if you haven't completed the Foursquare API lab
import folium # map rendering library

print('Libraries imported.')
# Out:
# Libraries imported.

# %%
#Load the table into a data frame
data = []
table = soup.find('table', attrs={'class':'wikitable sortable'})

# %%
#Parse the table and get a list 
#Transfer the list and get the original data into data frame

table_body = table.find('tbody')
table_rows = table.find_all('tr')
l = []
for tr in table_rows:
    td = tr.find_all('td')
    row = [tr.text.strip() for tr in td]
    l.append(row)
columnsList = ["Rank","ZipCode","Per capita income","Median household income","Median family income","Population","Number of households"]

df=pd.DataFrame(l, columns=columnsList)

df.head()
# Out:
#    Rank                     ZipCode Per capita income Median household income  \
# 0  None                        None              None                    None
# 1     1  02110 (Financial District)          $152,007                $123,795
# 2     2   02199 (Prudential Center)          $151,060                $107,159
# 3     3          02210 (Fort Point)           $93,078                $111,061
# 4     4           02109 (North End)           $88,921                $128,022
#
#   Median family income Population Number of households
# 0                 None       None                 None
# 1             $196,518      1,486                  981
# 2             $146,786      1,290                  823
# 3             $223,411      1,905                1,088
# 4             $162,045      4,277                2,190

# %%
#Function to find value between parentheses 
def extractArea(s):
    if(s == None):
        return None
    start = s.find('(')
    if start == -1:
        # No opening bracket found. Should this be an error?
        return ''
    start += 1  # skip the bracket, move to the next character
    end = s.find(')', start)
    if end == -1:
        # No closing bracket found after the opening bracket.
        # Should this be an error instead?
        return s[start:]
    else:
        return s[start:end]

# %%
#Function to find real zipcode 
def extractZip(s):
    if(s == None):
        return None
    start = s.find('(')
    if start == -1:
        # No opening bracket found. Should this be an error?
        return ''
    else:
        return s[0:start]

# %%
#Split the ZipCode column 
#Get ZipCode and Area into sepearte column
searchArea=[]
searchZip=[]

for values in df['ZipCode']:
    a=extractArea(values)
    z=s=extractZip(values)
    searchArea.append(a)
    searchZip.append(z)

df['Area']=searchArea
df['ZipCode']=searchZip

# %%
#Clean up the data
#Only process the cells that have zip code
df1=df.loc[(df['ZipCode'] != '') & (df['ZipCode'].notnull())].sort_values('Area').reset_index(drop=True)
df1.head()
# Out:
#   Rank ZipCode Per capita income Median household income Median family income  \
# 0   19  02134            $25,319                 $37,638              $49,355
# 1   24  02163            $21,915                 $43,889              $91,190
# 2    5  02116            $81,458                 $87,630             $134,875
# 3   25  02115            $21,654                 $23,677              $50,303
# 4    6  02108            $78,569                 $95,753             $153,618
#
#   Population Number of households                             Area
# 0     20,478                8,916                          Allston
# 1      1,842                  562  Allston-Harvard Business School
# 2     21,318               10,938             Back Bay/Bay Village
# 3     29,178                9,958          Back Bay/Fenway–Kenmore
# 4      4,155                2,337   Beacon Hill/Financial District

# %%
import geocoder
from geopy.geocoders import Nominatim
geolocator = Nominatim()
# Out:
# /home/jupyterlab/conda/lib/python3.6/site-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning

# %%
#Get coordinates from zipCode
searchLatitude=[]
searchLongitude=[]

for zipCode in df1['ZipCode']:
    location = geolocator.geocode(zipCode)
    searchLatitude.append(location.latitude)
    searchLongitude.append(location.longitude)

df1['Latitude']=searchLatitude
df1['Longitude']=searchLongitude

# %%
df1.head()
# Out:
#   Rank ZipCode Per capita income Median household income Median family income  \
# 0   19  02134            $25,319                 $37,638              $49,355
# 1   24  02163            $21,915                 $43,889              $91,190
# 2    5  02116            $81,458                 $87,630             $134,875
# 3   25  02115            $21,654                 $23,677              $50,303
# 4    6  02108            $78,569                 $95,753             $153,618
#
#   Population Number of households                             Area   Latitude  \
# 0     20,478                8,916                          Allston  42.356341
# 1      1,842                  562  Allston-Harvard Business School  54.664780
# 2     21,318               10,938             Back Bay/Bay Village  42.349825
# 3     29,178                9,958          Back Bay/Fenway–Kenmore  42.341128
# 4      4,155                2,337   Beacon Hill/Financial District  42.357660
#
#    Longitude
# 0 -71.135159
# 1  25.280405
# 2 -71.073294
# 3 -71.095119
# 4 -71.064266

# %%
#Fix the coordinates for 02122 since it's not accurate in geocoder
df2=df1.sort_values('Area').copy()
df2.loc[df2['ZipCode'].astype(int) ==2122, ['Latitude']] =42.2967
df2.loc[df2['ZipCode'].astype(int) == 2122, ['Longitude']] =-71.0527
df2.reindex()
#show full list of areas
df2
# Out:
#    Rank ZipCode Per capita income Median household income  \
# 0    19  02134            $25,319                 $37,638
# 1    24  02163            $21,915                 $43,889
# 2     5  02116            $81,458                 $87,630
# 3    25  02115            $21,654                 $23,677
# 4     6  02108            $78,569                 $95,753
# 5     7  02114            $65,865                 $79,734
# 6    16  02135            $31,773                 $50,291
# 7     9  02129            $56,267                 $89,105
# 8    10  02467            $53,382                $113,952
# 9     8  02111            $56,716                 $44,758
# 10   22  02124            $23,115                 $48,329
# 11   21  02122            $23,432                 $51,798
# 12   29  02121            $18,226                 $30,419
# 13   23  02125            $22,158                 $42,298
# 14   20  02128            $23,450                 $49,549
# 15   27  02215            $19,082                 $30,823
# 16    1  02110           $152,007                $123,795
# 17    3  02210            $93,078                $111,061
# 18   18  02136            $28,009                 $57,080
# 19   14  02130            $42,916                 $74,198
# 20   26  02126            $20,649                 $43,532
# 21   30  02120            $17,390                 $32,367
# 22   11  02113            $52,905                 $64,413
# 23    4  02109            $88,921                $128,022
# 24    2  02199           $151,060                $107,159
# 25   17  02131            $29,486                 $61,099
# 26   28  02119            $18,998                 $27,051
# 27   15  02127            $42,854                 $67,012
# 28   13  02118            $43,887                 $50,000
# 29   12  02132            $44,306                 $82,421
#
#    Median family income Population Number of households  \
# 0               $49,355     20,478                8,916
# 1               $91,190      1,842                  562
# 2              $134,875     21,318               10,938
# 3               $50,303     29,178                9,958
# 4              $153,618      4,155                2,337
# 5              $169,107     11,933                6,752
# 6               $62,602     38,839               18,336
# 7               $98,445     17,052                8,083
# 8              $148,396     22,796                6,351
# 9               $88,333      7,616                3,390
# 10              $55,031     49,867               17,275
# 11              $50,246     25,437                8,216
# 12              $35,439     26,801                9,739
# 13              $44,397     31,996               11,481
# 14              $49,470     41,680               14,965
# 15              $72,583     23,719                7,995
# 16             $196,518      1,486                  981
# 17             $223,411      1,905                1,088
# 18              $74,734     29,219               10,650
# 19              $95,426     36,866               15,306
# 20              $52,774     27,335                9,510
# 21              $29,583     13,217                4,509
# 22             $112,589      7,276                4,329
# 23             $162,045      4,277                2,190
# 24             $146,786      1,290                  823
# 25              $70,598     30,370               11,282
# 26              $35,311     24,237                9,769
# 27              $68,110     32,547               14,994
# 28              $49,090     26,779               12,512
# 29             $110,219     27,163               11,013
#
#                                              Area   Latitude  Longitude
# 0                                         Allston  42.356341 -71.135159
# 1                 Allston-Harvard Business School  54.664780  25.280405
# 2                            Back Bay/Bay Village  42.349825 -71.073294
# 3                         Back Bay/Fenway–Kenmore  42.341128 -71.095119
# 4                  Beacon Hill/Financial District  42.357660 -71.064266
# 5                            Beacon Hill/West End  42.349411 -71.061651
# 6                                        Brighton  42.358197 -71.144008
# 7                                     Charlestown  42.377543 -71.061422
# 8                                   Chestnut Hill  42.320017 -71.158139
# 9   Chinatown/Financial District/Leather District  42.352139 -71.060927
# 10               Dorchester-Codman Square-Ashmont  42.286449 -71.073345
# 11                       Dorchester-Fields Corner  42.296700 -71.052700
# 12                       Dorchester-Mount Bowdoin  42.307544 -71.081212
# 13            Dorchester-Uphams Corner-Savin Hill  42.320038 -71.055724
# 14                                    East Boston  42.369152 -71.062109
# 15                                 Fenway-Kenmore  42.347941 -71.103793
# 16                             Financial District  42.356321 -71.053639
# 17                                     Fort Point  42.349645 -71.045786
# 18                                      Hyde Park  42.258241 -71.125550
# 19                                  Jamaica Plain  42.313266 -71.109675
# 20                                       Mattapan  42.276022 -71.086399
# 21                                   Mission Hill  49.894075   3.645358
# 22                                      North End  42.361168 -71.056318
# 23                                      North End  42.360052 -71.054678
# 24                              Prudential Center  42.346598 -71.081598
# 25                                     Roslindale  42.286038 -71.132707
# 26                                        Roxbury  42.325386 -71.084964
# 27                                   South Boston  42.336963 -71.053066
# 28                                      South End  42.339066 -71.071522
# 29                                   West Roxbury  42.283349 -71.154845

# %%
# Draw a map of Boston and mark all neighborhood
address = 'Boston, MA'

location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print('The geograpical coordinate of Boston are {}, {}.'.format(latitude, longitude))
# create map of Boston using latitude and longitude values
map_Boston = folium.Map(location=[latitude, longitude], zoom_start=10)

# add markers to map
for lat, lng, neighborhood, zipCode in zip(df2['Latitude'], df2['Longitude'], df2['Area'],df2['ZipCode']):
    label = neighborhood + ' (' + zipCode + ')'
    label = folium.Popup(label, parse_html=True)
    folium.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        color='blue',
        fill=True,
        fill_color='#3186cc',
        fill_opacity=0.7,
        parse_html=False).add_to(map_Boston)  
    
map_Boston
# Out:
# The geograpical coordinate of Boston are 42.3602534, -71.0582912.
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
#Initial FourSqure
CLIENT_ID = '31ZXKBSCYIY1HTQKYQ02IQVYQKSYHQDYX0CMFPSK0MJKNI2S' # your Foursquare ID
CLIENT_SECRET = '3YTYLGJI5OYLMPNWNAQEIRY4XU11KXQFMQECWA1JA3FRC1FM' # your Foursquare Secret
VERSION = '20180605' # Foursquare API version
# type your answer here
radius=500
LIMIT=200
#CATEGORY_ID = '4d4b7105d754a06374d81259' #Category for food 
CATEGORY_ID = '4bf58dd8d48988d11f941735' #Night Clu

# %%
def getNearbyCategoryVenues(names, latitudes, longitudes, zipCode, radius=5000):
    
    venues_list=[]
    for name, lat, lng, zipCode in zip(names, latitudes, longitudes, zipCode):
        print(name + '(' + zipCode + ')')
        #print(name)
        #print(zip)
            
        # create the API request URL
        url = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}&categoryId={}'.format(
            CLIENT_ID, 
            CLIENT_SECRET, 
            VERSION, 
            lat, 
            lng, 
            radius, 
            LIMIT,
            CATEGORY_ID)
        print(url)    
        # make the GET request
        results = requests.get(url).json()["response"]['groups'][0]['items']
        
        # return only relevant information for each nearby venue
        venues_list.append([(
            name + ' (' + zipCode + ')', 
            name,
            zipCode,
            lat, 
            lng, 
            v['venue']['name'], 
            v['venue']['location']['lat'], 
            v['venue']['location']['lng'],  
            v['venue']['categories'][0]['name']) for v in results])

    nearby_venues = pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns = 
#
#    Neighborhood Longitude                Venue  Venue Latitude  \
# 0              -71.135159               Oberon       42.370759
# 1              -71.135159          Havana Club       42.364659
# 2              -71.135159  The Phoenix Landing       42.364178
# 3              -71.135159           Wonder Bar       42.350876
# 4              -71.135159          Club Passim       42.374330
#
#    Venue Longitude Venue Category
# 0       -71.114599      Nightclub
# 1       -71.104323      Nightclub
# 2       -71.101817      Nightclub
# 3       -71.131267      Nightclub
# 4       -71.120083      Nightclub

# %%
#df3 = Boston_food_venues.groupby(['NeighborhoodFull','Neighborhood','ZipCode']).size()
df3=Boston_venues.groupby(['Neighborhood','ZipCode']).count().reset_index()
df3
# Out:
#                                      Neighborhood ZipCode  NeighborhoodFull  \
# 0                                         Allston  02134                 20
# 1                 Allston-Harvard Business School  02163                 28
# 2                            Back Bay/Bay Village  02116                 46
# 3                         Back Bay/Fenway–Kenmore  02115                 48
# 4                  Beacon Hill/Financial District  02108                 43
# 5                            Beacon Hill/West End  02114                 41
# 6                                        Brighton  02135                 18
# 7                                     Charlestown  02129                 41
# 8                                   Chestnut Hill  02467                  5
# 9   Chinatown/Financial District/Leather District  02111                 40
# 10               Dorchester-Codman Square-Ashmont  02124                  5
# 11                       Dorchester-Fields Corner  02122                  6
# 12                       Dorchester-Mount Bowdoin  02121                 18
# 13            Dorchester-Uphams Corner-Savin Hill  02125                 35
# 14                                    East Boston  02128                 41
# 15                                 Fenway-Kenmore  02215                 48
# 16                             Financial District  02110                 38
# 17                                     Fort Point  02210                 37
# 18                                      Hyde Park  02136                  4
# 19                                  Jamaica Plain  02130                 13
# 20                                       Mattapan  02126                  4
# 21                                      North End  02109                 38
# 22                                      North End  02113                 39
# 23                              Prudential Center  02199                 48
# 24                                     Roslindale  02131                  3
# 25                                        Roxbury  02119                 44
# 26                                   South Boston  02127                 38
# 27                                      South End  02118                 42
# 28                                   West Roxbury  02132                  3
#
#     Neighborhood Latitude  Neighborhood Longitude  Venue  Venue Latitude  \
# 0                      20                      20     20              20
# 1                      28                      28     28              28
# 2                      46                      46     46              46
# 3                      48                      48     48              48
# 4                      43                      43     43              43
# 5                      41                      41     41              41
# 6                      18                      18     18              18
# 7                      41                      41     41              41
# 8                       5                       5      5               5
# 9                      40                      40     40              40
# 10                      5                       5      5               5
# 11                      6                       6      6               6
# 12                     18                      18     18              18
# 13                     35                      35     35              35
# 14                     41                      41     41              41
# 15                     48                      48     48              48
# 16                     38                      38     38              38
# 17                     37                      37     37              37
# 18                      4                       4      4               4
# 19                     13                      13     13              13
# 20                      4                       4      4               4
# 21                     38                      38     38              38
# 22                     39                      39     39              39
# 23                     48                      48     48              48
# 24                      3                       3      3               3
# 25                     44                      44     44              44
# 26                     38                      38     38              38
# 27                     42                      42     42              42
# 28                      3                       3      3               3
#
#     Venue Longitude  Venue Category
# 0                20              20
# 1                28              28
# 2                46              46
# 3                48              48
# 4                43              43
# 5                41              41
# 6                18              18
# 7                41              41
# 8                 5               5
# 9                40              40
# 10                5               5
# 11                6               6
# 12               18              18
# 13               35              35
# 14               41              41
# 15               48              48
# 16               38              38
# 17               37              37
# 18                4               4
# 19               13              13
# 20                4               4
# 21               38              38
# 22               39              39
# 23               48              48
# 24                3               3
# 25               44              44
# 26               38              38
# 27               42              42
# 28                3               3

# %%
dfAll = pd.merge(df3[['ZipCode', 'Neighborhood', 'Venue']],df2[["ZipCode","Area","Per capita income","Median household income","Median family income","Population","Number of households"]],
                       how='right', on=['ZipCode'])
dfAll.loc[dfAll['Area'] == 'Mission Hill', ['Neighborhood']] ='Mission Hill'
dfAll.loc[dfAll['Area'] == 'Mission Hill', ['Venue']] =0
dfAll
# Out:
#    ZipCode                                   Neighborhood  Venue  \
# 0   02134                                         Allston   20.0
# 1   02163                 Allston-Harvard Business School   28.0
# 2   02116                            Back Bay/Bay Village   46.0
# 3   02115                         Back Bay/Fenway–Kenmore   48.0
# 4   02108                  Beacon Hill/Financial District   43.0
# 5   02114                            Beacon Hill/West End   41.0
# 6   02135                                        Brighton   18.0
# 7   02129                                     Charlestown   41.0
# 8   02467                                   Chestnut Hill    5.0
# 9   02111   Chinatown/Financial District/Leather District   40.0
# 10  02124                Dorchester-Codman Square-Ashmont    5.0
# 11  02122                        Dorchester-Fields Corner    6.0
# 12  02121                        Dorchester-Mount Bowdoin   18.0
# 13  02125             Dorchester-Uphams Corner-Savin Hill   35.0
# 14  02128                                     East Boston   41.0
# 15  02215                                  Fenway-Kenmore   48.0
# 16  02110                              Financial District   38.0
# 17  02210                                      Fort Point   37.0
# 18  02136                                       Hyde Park    4.0
# 19  02130                                   Jamaica Plain   13.0
# 20  02126                                        Mattapan    4.0
# 21  02109                                       North End   38.0
# 22  02113                                       North End   39.0
# 23  02199                               Prudential Center   48.0
# 24  02131                                      Roslindale    3.0
# 25  02119                                         Roxbury   44.0
# 26  02127                                    South Boston   38.0
# 27  02118                                       South End   42.0
# 28  02132                                    West Roxbury    3.0
# 29  02120                                    Mission Hill    0.0
#
#                                              Area Per capita income  \
# 0                                         Allston           $25,319
# 1                 Allston-Harvard Business School           $21,915
# 2                            Back Bay/Bay Village           $81,458
# 3                         Back Bay/Fenway–Kenmore           $21,654
# 4                  Beacon Hill/Financial District           $78,569
# 5                            Beacon Hill/West End           $65,865
# 6                                        Brighton           $31,773
# 7                                     Charlestown           $56,267
# 8                                   Chestnut Hill           $53,382
# 9   Chinatown/Financial District/Leather District           $56,716
# 10               Dorchester-Codman Square-Ashmont           $23,115
# 11                       Dorchester-Fields Corner           $23,432
# 12                       Dorchester-Mount Bowdoin           $18,226
# 13            Dorchester-Uphams Corner-Savin Hill           $22,158
# 14                                    East Boston           $23,450
# 15                                 Fenway-Kenmore           $19,082
# 16                             Financial District          $152,007
# 17                                     Fort Point           $93,078
# 18                                      Hyde Park           $28,009
# 19                                  Jamaica Plain           $42,916
# 20                                       Mattapan           $20,649
# 21                                      North End           $88,921
# 22                                      North End           $52,905
# 23                              Prudential Center          $151,060
# 24                                     Roslindale           $29,486
# 25                                        Roxbury           $18,998
# 26                                   South Boston           $42,854
# 27                                      South End           $43,887
# 28                                   West Roxbury           $44,306
# 29                                   Mission Hill           $17,390
#
#    Median household income Median family income Population  \
# 0                  $37,638              $49,355     20,478
# 1                  $43,889              $91,190      1,842
# 2                  $87,630             $134,875     21,318
# 3                  $23,677              $50,303     29,178
# 4                  $95,753             $153,618      4,155
# 5                  $79,734             $169,107     11,933
# 6                  $50,291              $62,602     38,839
# 7                  $89,105              $98,445     17,052
# 8                 $113,952             $148,396     22,796
# 9                  $44,758              $88,333      7,616
# 10                 $48,329              $55,031     49,867
# 11                 $51,798              $50,246     25,437
# 12                 $30,419              $35,439     26,801
# 13                 $42,298              $44,397     31,996
# 14                 $49,549              $49,470     41,680
# 15                 $30,823              $72,583     23,719
# 16                $123,795             $196,518      1,486
# 17                $111,061             $223,411      1,905
# 18                 $57,080              $74,734     29,219
# 19                 $74,198              $95,426     36,866
# 20                 $43,532              $52,774     27,335
# 21                $128,022             $162,045      4,277
# 22                 $64,413             $112,589      7,276
# 23                $107,159             $146,786      1,290
# 24                 $61,099              $70,598     30,370
# 25                 $27,051              $35,311     24,237
# 26                 $67,012              $68,110     32,547
# 27                 $50,000              $49,090     26,779
# 28                 $82,421             $110,219     27,163
# 29                 $32,367              $29,583     13,217
#
#    Number of households
# 0                 8,916
# 1                   562
# 2                10,938
# 3                 9,958
# 4                 2,337
# 5                 6,752
# 6                18,336
# 7                 8,083
# 8                 6,351
# 9                 3,390
# 10               17,275
# 11                8,216
# 12                9,739
# 13               11,481
# 14               14,965
# 15                7,995
# 16                  981
# 17                1,088
# 18               10,650
# 19               15,306
# 20                9,510
# 21                2,190
# 22                4,329
# 23                  823
# 24               11,282
# 25                9,769
# 26               14,994
# 27               12,512
# 28               11,013
# 29                4,509

# %%
dfAll['Per capita income']=dfAll['Per capita income'].str.replace('$','').str.replace(',','').astype(int)
dfAll['Median household income']=dfAll['Median household income'].str.replace('$','').str.replace(',','').astype(int)
dfAll['Median family income']=dfAll['Median family income'].str.replace('$','').str.replace(',','').astype(int)
dfAll['Population']=dfAll['Population'].str.replace(',','').astype(int)
dfAll['Number of households']=dfAll['Number of households'].str.replace(',','').astype(int)
dfAll
# Out:
#    ZipCode                                   Neighborhood  Venue  \
# 0   02134                                         Allston   20.0
# 1   02163                 Allston-Harvard Business School   28.0
# 2   02116                            Back Bay/Bay Village   46.0
# 3   02115                         Back Bay/Fenway–Kenmore   48.0
# 4   02108                  Beacon Hill/Financial District   43.0
# 5   02114                            Beacon Hill/West End   41.0
# 6   02135                                        Brighton   18.0
# 7   02129                                     Charlestown   41.0
# 8   02467                                   Chestnut Hill    5.0
# 9   02111   Chinatown/Financial District/Leather District   40.0
# 10  02124                Dorchester-Codman Square-Ashmont    5.0
# 11  02122                        Dorchester-Fields Corner    6.0
# 12  02121                        Dorchester-Mount Bowdoin   18.0
# 13  02125             Dorchester-Uphams Corner-Savin Hill   35.0
# 14  02128                                     East Boston   41.0
# 15  02215                                  Fenway-Kenmore   48.0
# 16  02110                              Financial District   38.0
# 17  02210                                      Fort Point   37.0
# 18  02136                                       Hyde Park    4.0
# 19  02130                                   Jamaica Plain   13.0
# 20  02126                                        Mattapan    4.0
# 21  02109                                       North End   38.0
# 22  02113                                       North End   39.0
# 23  02199                               Prudential Center   48.0
# 24  02131                                      Roslindale    3.0
# 25  02119                                         Roxbury   44.0
# 26  02127                                    South Boston   38.0
# 27  02118                                       South End   42.0
# 28  02132                                    West Roxbury    3.0
# 29  02120                                    Mission Hill    0.0
#
#                                              Area  Per capita income  \
# 0                                         Allston              25319
# 1                 Allston-Harvard Business School              21915
# 2                            Back Bay/Bay Village              81458
# 3                         Back Bay/Fenway–Kenmore              21654
# 4                  Beacon Hill/Financial District              78569
# 5                            Beacon Hill/West End              65865
# 6                                        Brighton              31773
# 7                                     Charlestown              56267
# 8                                   Chestnut Hill              53382
# 9   Chinatown/Financial District/Leather District              56716
# 10               Dorchester-Codman Square-Ashmont              23115
# 11                       Dorchester-Fields Corner              23432
# 12                       Dorchester-Mount Bowdoin              18226
# 13            Dorchester-Uphams Corner-Savin Hill              22158
# 14                                    East Boston              23450
# 15                                 Fenway-Kenmore              19082
# 16                             Financial District             152007
# 17                                     Fort Point              93078
# 18                                      Hyde Park              28009
# 19                                  Jamaica Plain              42916
# 20                                       Mattapan              20649
# 21                                      North End              88921
# 22                                      North End              52905
# 23                              Prudential Center             151060
# 24                                     Roslindale              29486
# 25                                        Roxbury              18998
# 26                                   South Boston              42854
# 27                                      South End              43887
# 28                                   West Roxbury              44306
# 29                                   Mission Hill              17390
#
#     Median household income  Median family income  Population  \
# 0                     37638                 49355       20478
# 1                     43889                 91190        1842
# 2                     87630                134875       21318
# 3                     23677                 50303       29178
# 4                     95753                153618        4155
# 5                     79734                169107       11933
# 6                     50291                 62602       38839
# 7                     89105                 98445       17052
# 8                    113952                148396       22796
# 9                     44758                 88333        7616
# 10                    48329                 55031       49867
# 11                    51798                 50246       25437
# 12                    30419                 35439       26801
# 13                    42298                 44397       31996
# 14                    49549                 49470       41680
# 15                    30823                 72583       23719
# 16                   123795                196518        1486
# 17                   111061                223411        1905
# 18                    57080                 74734       29219
# 19                    74198                 95426       36866
# 20                    43532                 52774       27335
# 21                   128022                162045        4277
# 22                    64413                112589        7276
# 23                   107159                146786        1290
# 24                    61099                 70598       30370
# 25                    27051                 35311       24237
# 26                    67012                 68110       32547
# 27                    50000                 49090       26779
# 28                    82421                110219       27163
# 29                    32367                 29583       13217
#
#     Number of households
# 0                   8916
# 1                    562
# 2                  10938
# 3                   9958
# 4                   2337
# 5                   6752
# 6                  18336
# 7                   8083
# 8                   6351
# 9                   3390
# 10                 17275
# 11                  8216
# 12                  9739
# 13                 11481
# 14                 14965
# 15                  7995
# 16                   981
# 17                  1088
# 18                 10650
# 19                 15306
# 20                  9510
# 21                  2190
# 22                  4329
# 23                   823
# 24                 11282
# 25                  9769
# 26                 14994
# 27                 12512
# 28                 11013
# 29                  4509

# %%
dfRank=dfAll.copy()
dfRank['PerCapitaIncomeRanked'] = dfRank['Per capita income'].rank(ascending=1)
dfRank['HouseholdSizeRanked'] = (dfRank['Population']/dfRank['Number of households']).rank(ascending=0)
dfRank['VenuePerPopulationRanked'] = (dfRank['Venue']/dfRank['Population']).rank(ascending=0)
# 2     21,318               10,938             Back Bay/Bay Village  42.349825
# 3     29,178                9,958          Back Bay/Fenway–Kenmore  42.341128
# 4      4,155                2,337   Beacon Hill/Financial District  42.357660
#
#    Longitude
# 0 -71.135159
# 1  25.280405
# 2 -71.073294
# 3 -71.095119
# 4 -71.064266

# %%
dfFinal = pd.merge(df2[['ZipCode','Latitude','Longitude']],dfRank[["Neighborhood","ZipCode","Score","bins"]],
                       how='left', on=['ZipCode'])
dfFinal
# Out:
#    ZipCode   Latitude  Longitude  \
# 0   02134   42.356341 -71.135159
# 1   02163   54.664780  25.280405
# 2   02116   42.349825 -71.073294
# 3   02115   42.341128 -71.095119
# 4   02108   42.357660 -71.064266
# 5   02114   42.349411 -71.061651
# 6   02135   42.358197 -71.144008
# 7   02129   42.377543 -71.061422
# 8   02467   42.320017 -71.158139
# 9   02111   42.352139 -71.060927
# 10  02124   42.286449 -71.073345
# 11  02122   42.296700 -71.052700
# 12  02121   42.307544 -71.081212
# 13  02125   42.320038 -71.055724
# 14  02128   42.369152 -71.062109
# 15  02215   42.347941 -71.103793
# 16  02110   42.356321 -71.053639
# 17  02210   42.349645 -71.045786
# 18  02136   42.258241 -71.125550
# 19  02130   42.313266 -71.109675
# 20  02126   42.276022 -71.086399
# 21  02120   49.894075   3.645358
# 22  02113   42.361168 -71.056318
# 23  02109   42.360052 -71.054678
# 24  02199   42.346598 -71.081598
# 25  02131   42.286038 -71.132707
# 26  02119   42.325386 -71.084964
# 27  02127   42.336963 -71.053066
# 28  02118   42.339066 -71.071522
# 29  02132   42.283349 -71.154845
#
#                                      Neighborhood  Score bins
# 0                                         Allston   48.0    1
# 1                 Allston-Harvard Business School   13.0    3
# 2                            Back Bay/Bay Village   61.0    0
# 3                         Back Bay/Fenway–Kenmore   26.0    2
# 4                  Beacon Hill/Financial District   55.0    0
# 5                            Beacon Hill/West End   59.0    0
# 6                                        Brighton   57.0    0
# 7                                     Charlestown   54.0    0
# 8                                   Chestnut Hill   46.0    1
# 9   Chinatown/Financial District/Leather District   49.0    1
# 10               Dorchester-Codman Square-Ashmont   44.0    1
# 11                       Dorchester-Fields Corner   36.0    1
# 12                       Dorchester-Mount Bowdoin   33.0    1
# 13            Dorchester-Uphams Corner-Savin Hill   34.0    1
# 14                                    East Boston   39.0    1
# 15                                 Fenway-Kenmore   20.0    3
# 16                             Financial District   62.0    0
# 17                                     Fort Point   58.0    0
# 18                                      Hyde Park   51.0    0
# 19                                  Jamaica Plain   55.0    0
# 20                                       Mattapan   38.0    1
# 21                                   Mission Hill   36.0    1
# 22                                      North End   55.0    0
# 23                                      North End   56.0    0
# 24                              Prudential Center   59.0    0
# 25                                     Roslindale   56.0    0
# 26                                        Roxbury   30.0    2
# 27                                   South Boston   51.0    0
# 28                                      South End   53.0    0
# 29                                   West Roxbury   61.0    0

# %%
#### create map
map_clusters = folium.Map(location=[latitude, longitude], zoom_start=11)

# set color scheme for the clusters
x = np.arange(4)
ys = [i+x+(i*x)**2 for i in range(4)]
colors_array = cm.rainbow(np.linspace(0, 1, len(ys)))
rainbow = [colors.rgb2hex(i) for i in colors_array]

# add markers to the map
markers_colors = []
for lat, lon, poi, cluster in zip(dfFinal['Latitude'], dfFinal['Longitude'], dfFinal['Neighborhood'], dfFinal['bins']):
    label = folium.Popup(str(poi) + ' Cluster ' + str(cluster), parse_html=True)
    folium.CircleMarker(
        [lat, lon],
        radius=5,
        popup=label,
        color=rainbow[cluster-1],
        fill=True,
        fill_color=rainbow[cluster-1],
        fill_opacity=0.7).add_to(map_clusters)
       
map_clusters
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
